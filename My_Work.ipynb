# %% [markdown]
# <a href="https://colab.research.google.com/github/Omolola56/My-Code/blob/main/My_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Students Performance Analyser
Name = 'Ganiyu Rashidat Omolola'
Age = 40
Department = "Art Education"

Mathematics = 78
Python = 81
Statistics = 80

Total_score = Mathematics + Python + Statistics
Average_score = Total_score / 3
Highest_score = Mathematics

if Python > Highest_score:
    Highest_score = Python
if Statistics > Highest_score:
    Highest_score = Statistics

Lowest_score = Mathematics

if Python < Lowest_score:
    Lowest_score = Python
if Statistics < Lowest_score:
    Lowest_score = Statistics

Pass = Average_score >= 50

print("Student Performance Analyser")
print("Name:", Name)
print("Age:", Age)
print("Department:", Department)
print("Mathematics:", Mathematics)
print("Python:", Python)
print("Statistics:", Statistics)
print("Total_score:", Total_score)
print("Average_score:", Average_score)
print("Highest_score:", Highest_score)
print("Lowest_score:", Lowest_score)

if Pass == True:
    print("Result: Pass")
else:
    print("Result: Fail")
# Out:
# Student Performance Analyser
# Name: Ganiyu Rashidat Omolola
# Age: 40
# Department: Art Education
# Mathematics: 78
# Python: 81
# Statistics: 80
# Total_score: 239
# Average_score: 79.66666666666667
# Highest_score: 81
# Lowest_score: 78
# Result: Pass
